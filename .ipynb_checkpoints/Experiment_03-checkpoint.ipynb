# %% [markdown]
# # outline
# + try antidifferentiation up to a known polynomial
# + track continuous deformation of the roots of derivatives

# %%
import numpy as np
import scipy.optimize as spopt
import sympy
from scipy.special import gamma
from polyrand import polyrand
import importlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
importlib.reload(polyrand)
# Out:
# <module 'polyrand.polyrand' from '/home/derek/repos/polyrand/polyrand/polyrand.py'>

# %% [markdown]
# Differentiate down to a degree 2 polynomial then antidifferentiate using the original coefficients.

# %%
polyrand.find_roots_x(20,correction=True)

# %%
polyrand.find_roots_x(15,correction=False)

# %%
polyrand.find_roots_x(15,stop_deg=12,perturb=[50,20])

# %%
polyrand.find_roots_x(75)
