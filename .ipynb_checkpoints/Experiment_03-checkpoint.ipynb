# %% [markdown]
# # outline
# + try antidifferentiation up to a known polynomial
# + track continuous deformation of the roots of derivatives

# %%
import numpy as np
import polyrand
import importlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
importlib.reload(polyrand)
# Out:
# <module 'polyrand' from '/Users/derekmiller/Desktop/D_stuff/polyrand/polyrand.py'>

# %%
params = [('normal',[0,1],{'size':10})]
polyrand.poly_roots(params,dx=5,basis='power',plot_range=3)
