# %%
import numpy as np
import importlib
from polyrand import rootfinder as rf
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
importlib.reload(rf)
# Out:
# <module 'polyrand.rootfinder' from '/Users/derekmiller/Desktop/D_stuff/polyrand/polyrand/rootfinder.py'>

# %%
P = np.polynomial.polynomial.Polynomial([-6.16,23.26,-16.84,-13.58,10.32,-19.98])

# %%
R = P.roots()

# %%
nmlist = rf.newton_method(.01+ 0.j,P)

# %%
fnmlist = rf.fractional_newton_method(.01+ 0.j,P,1.1)

# %%
plt.figure(figsize=(8,8))
X = np.linspace(-2,2,30)
#plt.plot(X,P(X),color='grey',lw=3,alpha=.5)
plt.scatter(nmlist.real,nmlist.imag,color='r',alpha=.5)
plt.scatter(R.real,R.imag)
plt.show()

# %%
plt.figure(figsize=(8,8))
#plt.plot(X,P(X),color='grey',lw=3,alpha=.5)
plt.scatter(fnmlist.real,fnmlist.imag,color='r',alpha=.5)
plt.scatter(R.real,R.imag)
plt.show()

# %%
fnmlist = rf.fractional_newton_method(.01+ 0.j,P,1.35)
plt.figure(figsize=(8,8))
#plt.plot(X,P(X),color='grey',lw=3,alpha=.5)
plt.scatter(fnmlist.real,fnmlist.imag,color='r',alpha=.5)
plt.scatter(R.real,R.imag)

plt.show()

# %%
fnmlist = rf.fractional_newton_method(.01+ 0.j,P,1.2)
plt.figure(figsize=(8,8))
#plt.plot(X,P(X),color='grey',lw=3,alpha=.5)
plt.scatter(fnmlist.real,fnmlist.imag,color='r',alpha=.5)
plt.scatter(R.real,R.imag)

plt.show()

# %%
fnmlist = rf.fractional_newton_method(.1+ 0.j,P,.5)
plt.figure(figsize=(8,8))
plt.plot(X,P(X),color='grey',lw=3,alpha=.5)
plt.scatter(fnmlist.real,fnmlist.imag,color='r',alpha=.5)
plt.axis('equal')
plt.show()

# %%
Q = np.polynomial.polynomial.Polynomial()
