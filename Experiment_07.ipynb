# %%
import numpy as np
import importlib
from polyrand import rootfinder as rf
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
importlib.reload(rf)
# Out:
# <module 'polyrand.rootfinder' from '/Users/derekmiller/Desktop/D_stuff/polyrand/polyrand/rootfinder.py'>

# %%
P = np.polynomial.polynomial.Polynomial([-6.16,23.26,-16.84,-13.58,10.32,-19.98])
R = P.roots()

# %%
fnmlist = rf.fractional_newton_method(P,.01+ 0.j,1.35)
print(len(fnmlist))
plt.figure(figsize=(8,8))
plt.scatter(fnmlist.real,fnmlist.imag,c=np.linspace(0,1,len(fnmlist)),alpha=.7)
#plt.scatter(R.real,R.imag,alpha=.1,s=500)
plt.axis('equal')

plt.show()
# Out:
# 135

# %%
rf.animate_frac_roots(P,.01+ 0.j,1.35,plot_range=[(-.3,1.4),(-.5,1)])
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
rf.animate_frac_roots(P,.01+ 0.j,1.5,plot_range=[(-1.4,.75), (-.1,1.3)])
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
fnmlist = rf.fractional_newton_method(P,.01+ 0.j,1.5)
print(len(fnmlist))
plt.figure(figsize=(8,8))
plt.scatter(fnmlist.real,fnmlist.imag,c=np.linspace(0,1,len(fnmlist)),alpha=.5)
#plt.scatter(R.real,R.imag,s=500,alpha=.3)

plt.show()
# Out:
# 99
