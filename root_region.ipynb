# %%
import numpy as np
np.random.seed(25)
from itertools import product
import scipy.stats
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import animation,rc
from IPython.display import HTML
import importlib

# %matplotlib inline

# %%
import polyrand
importlib.reload(polyrand)
# Out:
# <module 'polyrand' from '/media/derek/FAMHIST/polyrand.py'>

# %%
params = [('normal',[0,1],{'size':100})]
polyrand.poly_roots(params)

# %%
params = [('normal',[0,1],{'size':100})]
polyrand.poly_roots(params,dx=2,basis='power',plot_range=1)

# %%
params = [('normal',[0,1],{'size':100})]
polyrand.poly_roots(params,dx=10)

# %%
params = [('normal',[0,1],{'size':100})]
polyrand.poly_roots(params,dx=20)

# %%
params = [('normal',[0,1],{'size':100})]
polyrand.poly_roots(params,dx=40)

# %%
params = [('normal',[0,1],{'size':100})]
polyrand.poly_roots(params,dx=100)

# %%
params = [('normal',[0,1],{'size':100})]
polyrand.poly_roots(params,dx=-1,plot_range=1)

# %%
params = [('normal',[0,1],{'size':100})]
polyrand.poly_roots(params,dx=-5)

# %%
params = [('normal',[0,1],{'size':100})]
polyrand.poly_roots(params,dx=-15)

# %%
params = [('normal',[0,1],{'size':100})]
polyrand.poly_roots(params,dx=-20)

# %%
params = [('normal',[0,1],{'size':100})]
polyrand.poly_roots(params,dx=-40)

# %%
params = [('normal',[0,1],{'size':100})]
polyrand.poly_roots(params,dx=-50)

# %%
params = [('normal',[0,1],{'size':100})]
polyrand.poly_roots(params,dx=-100)

# %%
#params = [('beta',[.5,.5],{'size':25}), ('gamma',[2,2],{'size':25}), ('normal',[0,1],{'size':25})]
#params = [('normal',[0,1],{'size':25}), ('gamma',[2,2],{'size':25}), ('beta',[.5,.5],{'size':25})]
#params = [('gamma',[2,2],{'size':100})]
params = [('normal',[0,1],{'size':100})]

# try also with chebyshev basis

X,Y,dX,dY = polyrand.poly_roots(params,basis='power',dx=100,return_values=True)

fig = plt.figure(figsize=(8,8))
ax = plt.gca()

plt.xlim((-1,1))
plt.ylim((-1,1))

line, = plt.plot([], [], 'ro', alpha=.4)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# animation function. This is called sequentially
def animate(i):
    x = dX[i]
    y = dY[i]
    line.set_data(x, y)
    return (line,)

# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=100, interval=100, blit=True)

HTML(anim.to_html5_video())
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# ANTIDERIVATIVES (with added standard normal constant)
params = [('normal',[0,1],{'size':100})] # basis='chebyshev'

X,Y,dX,dY = polyrand.poly_roots(params,basis='power',dx=-100,return_values=True)

fig = plt.figure(figsize=(8,8))
ax = plt.gca()

plt.xlim((-10,10))
plt.ylim((-10,10))

line, = plt.plot([], [], 'ro', alpha=.4)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# animation function. This is called sequentially
def animate(i):
    x = dX[i]
    y = dY[i]
    line.set_data(x, y)
    return (line,)

# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=100, interval=200, blit=True)

HTML(anim.to_html5_video())
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...
